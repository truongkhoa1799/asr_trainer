# %%
import pandas as pd

import pandas as pd

import sys
sys.path.append("/home/khoatlv/ASR_Nemo")
from conformer_asr.utils import Logger, read_manifest, config

evaluation_config = config.get_config(["evaluation"])
data = pd.read_csv(evaluation_config.result.log_data_result_path)
data.head()
# Out:
#                                       audio_filepath  \
# 0  /home/khoatlv/data/infore/infore_415h/book_rel...
# 1  /home/khoatlv/data/infore/infore_415h/book_rel...
# 2  /home/khoatlv/data/infore/infore_415h/book_rel...
# 3  /home/khoatlv/data/infore/infore_415h/book_rel...
# 4  /home/khoatlv/data/infore/infore_415h/book_rel...
#
#                                    ground_truth_text  \
# 0  tin rằng bạch hạc vốn là loại cầm thú nên khôn...
# 1  lưu dụ càng trở nên khó coi hắn bị chọc cúc ho...
# 2  cùng với hòa thái đầu hội họp ở một nơi tăm tố...
# 3  từ hình dáng bên ngoài nhiều người cho rằng hắ...
# 4  giang thanh liếc nhanh về phía phát ra tiếng r...
#
#                                     transcribed_text       wer
# 0  tin rằng bạch hạc vốn là loại cầm thú nên khôn...  0.000000
# 1  lưu dụ càng trở nên khó coi hắn bị chọc cúp qu...  0.100000
# 2  cùng với hòa thái đầu hội học ở một nơi tăm tố...  0.050000
# 3  từ hình dáng bên ngoài nhiều người cho rằng an...  0.125000
# 4  giang thanh liếc nhanh về phía phát ra tiếng r...  0.054054

# %%
data['wer'].describe()
# Out:
# count    315449.000000
# mean          0.137990
# std           0.143461
# min           0.000000
# 25%           0.052632
# 50%           0.103448
# 75%           0.181818
# max           1.066667
# Name: wer, dtype: float64

# %%
data[data['wer'] >= 1]
# Out:
#                                            audio_filepath  \
# 2464    /home/khoatlv/data/infore/infore_415h/book_rel...
# 6623    /home/khoatlv/data/infore/infore_415h/book_rel...
# 12284   /home/khoatlv/data/infore/infore_415h/book_rel...
# 19274   /home/khoatlv/data/infore/infore_415h/book_rel...
# 40502   /home/khoatlv/data/infore/infore_415h/book_rel...
# 45717   /home/khoatlv/data/infore/infore_415h/book_rel...
# 54259   /home/khoatlv/data/infore/infore_415h/book_rel...
# 73459   /home/khoatlv/data/infore/infore_415h/book_rel...
# 78307   /home/khoatlv/data/infore/infore_415h/book_rel...
# 79533   /home/khoatlv/data/infore/infore_415h/book_rel...
# 92037   /home/khoatlv/data/infore/infore_415h/book_rel...
# 99119   /home/khoatlv/data/infore/infore_415h/book_rel...
# 118751  /home/khoatlv/data/infore/infore_415h/book_rel...
# 121387  /home/khoatlv/data/infore/infore_415h/book_rel...
# 122072  /home/khoatlv/data/infore/infore_415h/book_rel...
# 124735  /home/khoatlv/data/infore/infore_415h/book_rel...
# 126549  /home/khoatlv/data/infore/infore_415h/book_rel...
# 151779  /home/khoatlv/data/infore/infore_415h/book_rel...
# 167816  /home/khoatlv/data/infore/infore_415h/book_rel...
# 197022  /home/khoatlv/data/infore/infore_415h/book_rel...
# 213007  /home/khoatlv/data/infore/infore_415h/book_rel...
# 245740  /home/khoatlv/data/infore/infore_415h/book_rel...
# 252918  /home/khoatlv/data/infore/infore_415h/book_rel...
# 303908  /home/khoatlv/data/infore/infore_415h/book_rel...
#
#                                         ground_truth_text  \
# 2464    này hắn mới cảm thán những ngọn núi vư...
# 6623    bọn hắn bị đánh hôm nay rốt cuộc có thê...
# 12284    trầm xuống lập tức có chút hoàn hãn nói
# 19274   tam thúc thường xuyên tìm hắn gây chuyện thậm chí
# 40502   những người này hoàn toàn chính là khôn...
# 45717    lẽ muốn hấp dẫn sự chú ý của mọi người
# 54259   màn này chỉ sợ người bình thường khó c...
# 73459   lồ phi linh môn đã hoàn toàn chiếm được ...
# 78307   chỉ sợ là vũ tướng ngũ trọng nó cũng ...
# 79533              không có người sỉ nhục hắn ngay cả thị
# 92037   là người nổi bật trong các thế lực lớn...
# 99119   chính là sự kiện mà toàn bộ đại lục n...
# 118751  nhưng hoàn cảnh đã rèn luyện lòng chàng phẳng ...
# 121387  kình hải nói ánh mắt quét về phía lục...
# 122072          danh nhưng muốn trở thành đệ tử ngoại môn
# 124735     cấp sơ giai này tuyệt đối thích hợp với
# 126549  tổn hại nào đều có thể tạo thành thươn...
# 151779  kích oành oành oành bảy chiếc quan tài đồng th...
# 167816  nào hắn mới có thể đạt được tới trình...
# 197022  khán đài chúng cường giả lúc này cũng ...
# 213007          các ngươi cẩn thận một chút trong thôn đã
# 245740          tàn lão thôn trong bóng tối không biết có
# 252918  tội lúc này lại thành người chịu oan kh...
# 303908     trường long còn được gọi là thú vương ta
#
#                                          transcribed_text       wer
# 2464    ngày hắn mới cảm tháng những ngọn núi vừa rồi ...  1.000000
# 6623    thường bọn hắn bị đánh cùng ngay rút cục có th...  1.000000
# 12284           trầm xuống lập tức có chút hoàng hãng nói  1.000000
# 19274     sau đó còn phải thường xuyên rèn luyện chân khí  1.000000
# 40502   những người này hoàn toàn chính là không để ý ...  1.066667
# 45717              lẽ muốn hấp dẫn sự chú ý của mọi người  1.000000
# 54259   màn này chỉ sợ người bình thường khó có thể ch...  1.000000
# 73459          linh môn đa hoàn toàn chiếm được đại thắng  1.000000
# 78307   chỉ sợ là vũ tướng ngũ trọng nó cũng có thể đá...  1.000000
# 79533                     về sau người sẽ có hứng thú đấy  1.000000
# 92037          đều là người nổi bật trong các thế lực lớn  1.000000
# 99119        chính là sự kiện mà toàn bộ đại lục nhìn vào  1.000000
# 118751  mỹ nhân đã ra hơn khiến cho lòng chàng phải ng...  1.000000
# 121387  hình hải nói anh mắt quét về phía lục thiếu du...  1.000000
# 122072     quang trên không trung vẽ thành một người sáng  1.000000
# 124735             sơ ri này tuyệt đối thích hợp với nàng  1.000000
# 126549  hai nào đều có thể tạo thành thương tổn trí mạ...  1.000000
# 151779  vềngờảnhhườngảnhbẩy trước quan thải đồng thời ...  1.000000
# 167816        nào ăn mới có thể đạt được tới trình độ này  1.000000
# 197022  táng đài chúng cường giả lúc này cũng cảm thấy...  1.000000
# 213007            cái nho nhỏ thanh long tồn tại trong đó  1.000000
# 245740         thành này ngay tại trong núi rừng đi đường  1.000000
# 252918  đội lúc này lại thành người trị hoan khuất bị ...  1.000000
# 303908          cung trứng lòng còn được gọi là thú vương  1.000000

# %%
data['wer'] = data['wer'].round(decimals=1)
data.groupby('wer').size()
# Out:
# wer
# 0.0     77064
# 0.1    129049
# 0.2     71275
# 0.3     18980
# 0.4      6621
# 0.5      2430
# 0.6      2627
# 0.7      3680
# 0.8      3088
# 0.9       594
# 1.0        40
# 1.1         1
# dtype: int64

# %%
wer = 0.3
bad_data = data[data['wer'] >= wer]
bad_data
# Out:
#                                            audio_filepath  \
# 8       /home/khoatlv/data/infore/infore_415h/book_rel...
# 14      /home/khoatlv/data/infore/infore_415h/book_rel...
# 19      /home/khoatlv/data/infore/infore_415h/book_rel...
# 20      /home/khoatlv/data/infore/infore_415h/book_rel...
# 41      /home/khoatlv/data/infore/infore_415h/book_rel...
# ...                                                   ...
# 315389  /home/khoatlv/data/infore/infore_415h/book_rel...
# 315390  /home/khoatlv/data/infore/infore_415h/book_rel...
# 315403  /home/khoatlv/data/infore/infore_415h/book_rel...
# 315415  /home/khoatlv/data/infore/infore_415h/book_rel...
# 315433  /home/khoatlv/data/infore/infore_415h/book_rel...
#
#                                         ground_truth_text  \
# 8       chưởng khí vừa phát lưu chí nhẫn đã sàn bộ tốn...
# 14      xem ra lực mê hoặc của vũ kỹ huyền cấp ...
# 19      một lần nữa lão nhân cái bang lại thộp cứng mạ...
# 20      bối bối tinh thần tham trắc cộng hưởng bao p...
# 41      rất tốt tiểu tháp cất hỗn độn nguyên thạch đ...
# ...                                                   ...
# 315389  khai vân vương không muốn láng giềng với cấm đ...
# 315390  cầm đầu là hắc long tư đồ chiêm tiếp theo là l...
# 315403  thời gian chớp nhoáng này chàng đã nhìn rõ tìn...
# 315415  tiên hơn ma vì bóng đỏ là một ác sát ác la sát là
# 315433  thế nhưng may mà linh tướng tứ trọng đỉn...
#
#                                          transcribed_text  wer
# 8       trường khí vừa pháp lưu trí nhẫn đã săn bộ tốn...  0.3
# 14      xem ra lược mê hoặc của vũ ký huyền cấp sơ rai...  0.7
# 19      một lần nữa lao nhân cái mang lại thuộc cứng m...  0.4
# 20      tinh thần hợấtlờ tham chắc cộng hưởng bao phụ ...  0.7
# 41      rất tốt tiểu tháp cất hỗn độn nguyên tạt đi sa...  0.3
# ...                                                   ...  ...
# 315389  khai dân dung không muốn lắng dền với cấm địa ...  0.4
# 315390  cầm đầu là hát long tư đồ chiêm tiếp theo là l...  0.3
# 315403  thời gian trước nhóm này trang đã nhìn rõ tỉnh...  0.3
# 315415  kém tiên hơn ma vì bóng đỏ là mùa tác xác ác l...  0.4
# 315433  thế nhưng may mà linh tướng tứ trọng đỉnh phon...  0.6
#
# [38061 rows x 4 columns]

# %%
# export_data.to_excel(evaluation_config.bad_data.bad_data_path_excel)
bad_data.to_csv(evaluation_config.bad_data.bad_data_path_csv, index=False)

# %%
# import json
# import os
# def remove_bad_data(bad_data_path_csv, error_data_path):
#     list_path = []
#     header = True
#     for i in open(bad_data_path_csv, mode='r', encoding='utf-8').readlines():
#         if header:
#             header = False
#             continue
#         line = i.split(',')
#         list_path.append(line[0])
    
    
#     for i in open(error_data_path, mode='r', encoding='utf-8').readlines():
#         list_path.append(i.strip())
    
#     count = 0
#     for i in list_path:
#         if not os.path.exists(i):
#             count += 1
    
#     print(len(list_path))
#     print(count)

# remove_bad_data(bad_data_path_csv, error_data_path)
# Out:
# 3473
# 3473

# %%
! wc -l /home/khoatlv/data/vlsp2020/manifests/vlsp2020_set_01_manifest.json
# Out:
# 122423 /home/khoatlv/data/vlsp2020/manifests/vlsp2020_set_01_manifest.json

# %%
print(118950 + 3473)
! wc -l /home/khoatlv/data/vlsp2020/manifests/vlsp2020_set_01_manifest.json
! wc -l /home/khoatlv/data/vlsp2020/manifests/vlsp2020_set_02_manifest.json

! wc -l /home/khoatlv/Conformer_ASR/scripts/evaluation/vlsp_01_eval_manifests.json
! wc -l /home/khoatlv/Conformer_ASR/scripts/evaluation/vlsp_02_eval_manifests.json
# Out:
# 122423
# 118950 /home/khoatlv/data/vlsp2020/manifests/vlsp2020_set_01_manifest.json
# 44554 /home/khoatlv/data/vlsp2020/manifests/vlsp2020_set_02_manifest.json
# 122423 /home/khoatlv/Conformer_ASR/scripts/evaluation/vlsp_01_eval_manifests.json
# 55188 /home/khoatlv/Conformer_ASR/scripts/evaluation/vlsp_02_eval_manifests.json

# %%
import playsound

playsound.playsound("/home/khoatlv/data/viettel/resample/21_hcm-diemmy_-1.wav")
# Out:
# playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/playsound.py", line 261, in <module>
#     playsound(argv[1])
#   File "/usr/local/lib/python3.8/dist-packages/playsound.py", line 162, in _playsoundNix
#     import gi
# ModuleNotFoundError: No module named 'gi'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /home/khoatlv/Conformer_ASR/scripts/evaluation/evaluate_result.ipynb Cell 10' in <cell line: 3>()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6e6f76615f617372222c2273657474696e6773223a7b22686f7374223a227373683a2f2f70686f7175616e227d7d/home/khoatlv/Conformer_ASR/scripts/evaluation/evaluate_result.ipynb#ch0000009vscode-remote?line=0'>1</a> import playsound
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6e6f76615f617372222c2273657474696e6773223a7b22686f7374223a227373683a2f2f70686f7175616e227d7d/home/khoatlv/Conformer_ASR/scripts/evaluation/evaluate_result.ipynb#ch0000009vscode-remote?line=2'>3</a> playsound.playsound("/home/khoatlv/data/viettel/resample/21_hcm-diemmy_-1.wav")
#
# File /usr/local/lib/python3.8/dist-packages/playsound.py:254, in <lambda>(sound, block)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=251'>252</a>         except:
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=252'>253</a>             logger.warning("playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.")
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=253'>254</a>             playsound = lambda sound, block = True: _playsoundAnotherPython('/usr/bin/python3', sound, block, macOS = False)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=255'>256</a> del system
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=257'>258</a> if __name__ == '__main__':
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=258'>259</a>     # block is always True if you choose to run this from the command line.
#
# File /usr/local/lib/python3.8/dist-packages/playsound.py:229, in _playsoundAnotherPython(otherPython, sound, block, macOS)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=226'>227</a> t.start()
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=227'>228</a> if block:
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=228'>229</a>     t.join()
#
# File /usr/local/lib/python3.8/dist-packages/playsound.py:218, in _playsoundAnotherPython.<locals>.PropogatingThread.join(self, timeout)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=215'>216</a> super().join(timeout)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=216'>217</a> if self.exc:
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=217'>218</a>     raise self.exc
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=218'>219</a> return self.ret
#
# File /usr/local/lib/python3.8/dist-packages/playsound.py:211, in _playsoundAnotherPython.<locals>.PropogatingThread.run(self)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=208'>209</a> self.exc = None
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=209'>210</a> try:
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=210'>211</a>     self.ret = self._target(*self._args, **self._kwargs)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=211'>212</a> except BaseException as e:
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=212'>213</a>     self.exc = e
#
# File /usr/local/lib/python3.8/dist-packages/playsound.py:226, in _playsoundAnotherPython.<locals>.<lambda>()
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=222'>223</a>     raise PlaysoundException('Cannot find a sound with filename: ' + sound)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=224'>225</a> playsoundPath = abspath(getsourcefile(lambda: 0))
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=225'>226</a> t = PropogatingThread(target = lambda: check_call([otherPython, playsoundPath, _handlePathOSX(sound) if macOS else sound]))
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=226'>227</a> t.start()
#     <a href='file:///usr/local/lib/python3.8/dist-packages/playsound.py?line=227'>228</a> if block:
#
# File /usr/lib/python3.8/subprocess.py:364, in check_call(*popenargs, **kwargs)
#     <a href='file:///usr/lib/python3.8/subprocess.py?line=361'>362</a>     if cmd is None:
#     <a href='file:///usr/lib/python3.8/subprocess.py?line=362'>363</a>         cmd = popenargs[0]
# --> <a href='file:///usr/lib/python3.8/subprocess.py?line=363'>364</a>     raise CalledProcessError(retcode, cmd)
#     <a href='file:///usr/lib/python3.8/subprocess.py?line=364'>365</a> return 0
#
# CalledProcessError: Command '['/usr/bin/python3', '/usr/local/lib/python3.8/dist-packages/playsound.py', '/home/khoatlv/data/viettel/resample/21_hcm-diemmy_-1.wav']' returned non-zero exit status 1.
